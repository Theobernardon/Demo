# %%
from csvannotator import csv_to_annotated_csv_pandas as to_annotated_csv
import pandas as pd

# %%
# Chemin vers le fichier CSV d'entrée
input_csv = "data\KAG_energydata_complete.csv"
# Chemin vers le fichier de sortie
output_csv = "data\data_influx.csv"

# Nom de la colonne qui contient la mesure
measurement_column = "Appliances"
# Colonnes à utiliser comme tags
tag_columns = []
# Colonnes à utiliser comme fields
field_columns = ["T1", "RH_1", "T2", "RH_2", "T3", "RH_3", "T4", "RH_4", "T5", "RH_5", "T6", "RH_6",
                 "T_out", "Press_mm_hg", "RH_out", "Wind_Speed", "Visibility", "Tdewpoint"]
# Nom de la colonne de timestamp (optionnel)
timestamp_column = "date"

# %%
to_annotated_csv(input_csv, output_csv,
                 measurement_column,
                 tag_columns,
                 field_columns,
                 timestamp_column)
